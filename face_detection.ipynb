# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamsikmk/cs8691-AIprojects/blob/master/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = 'object.jpg'
im = cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces, confidences = cv.detect_face(im)
for face in faces:
    (startX,startY) = face[0],face[1]
    (endX,endY) = face[2],face[3]
    cv2.rectangle(im, (startX,startY), (endX,endY), (0,255,0), 2)
plt.imshow(im)
plt.show
# Out:
# <function matplotlib.pyplot.show>
